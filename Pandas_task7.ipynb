# %% [markdown]
# #### Data Cleaning
# - Deal with structural errors, transformation and standardization..
#
# #### Data Manipulation
# - concatenate and merge the data.

# %%
import pandas as pd
import numpy as np
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\User\Downloads\data.xlsx",sheet_name=0)
df1 = pd.read_excel(r"C:\Users\User\Downloads\data.xlsx",sheet_name=1)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 1    536365     71053                  WHITE METAL LANTERN       #6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER        8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.        6
#
#    UnitPrice         Country
# 0       2.55  United Kingdom
# 1       3.39  United Kingdom
# 2       4.23  United Kingdom
# 3       5.07  United Kingdom
# 4       5.91  United Kingdom

# %%
df
# Out:
#     InvoiceNo StockCode                          Description Quantity  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 1      536365     71053                  WHITE METAL LANTERN       #6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER        8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.        6
# ..        ...       ...                                  ...      ...
# 229    536390     21485     RETROSPOT HEART HOT WATER BOTTLE       24
# 230    536390    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       24
# 231    536390    84030E        ENGLISH ROSE HOT WATER BOTTLE       24
# 232    536390     22174                           PHOTO CUBE       48
# 233    536390     22969         HOMEMADE JAM SCENTED CANDLES       96
#
#      UnitPrice         Country
# 0         2.55  United Kingdom
# 1         3.39  United Kingdom
# ...

# %% [markdown]
# ### Deal with structural errors,

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 1    536365     71053                  WHITE METAL LANTERN       #6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER        8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.        6
#
#    UnitPrice         Country
# 0       2.55  United Kingdom
# 1       3.39  United Kingdom
# 2       4.23  United Kingdom
# 3       5.07  United Kingdom
# 4       5.91  United Kingdom

# %%
df['InvoiceNo'] = df['InvoiceNo'].replace(r'C','',regex = True)

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('int32')

# %%
df['Quantity'] = df['Quantity'].replace(r'[-*# &]','',regex=True)

# %%
df['Quantity'] = df['Quantity'].astype('int32')

# %%
df['StockCode'] = df['StockCode'].replace(r'[ABCDEFGHIJHLMNOPQRSTUVWXYZ    ]','',regex=True)

# %%
df[1:50]
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# 5      536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6      536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7      536366     22633               HAND WARMER UNION JACK         6
# 8      536366     22632            HAND WARMER RED POLKA DOT         6
# 9      536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10     536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11     536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# 12     536367     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# ...

# %% [markdown]
# ### Transformation

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice         Country
# 0       2.55  United Kingdom
# 1       3.39  United Kingdom
# 2       4.23  United Kingdom
# 3       5.07  United Kingdom
# 4       5.91  United Kingdom

# %%
df['UnitPrice'].mean(),df['UnitPrice'].median()
# Out:
# (3.5843589743589743, 2.55)

# %%
df['UnitPrice'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['log_UnitPrice'] = np.log(df['UnitPrice'])

# %%
df['log_UnitPrice'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['log_UnitPrice'].mean(),df['log_UnitPrice'].median()     #Now the data is transformed becz there is little slight difference in mean and median
# Out:
# (0.9244664493557778, 0.9360933591703348)

# %%
df['Quantity'].mean(),df['Quantity'].median()
# Out:
# (23.22222222222222, 6.0)

# %%
df['Quantity'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['log_Quantity'] = np.log(df['Quantity'])

# %%
df['log_Quantity'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['log_Quantity'].mean(),df['log_Quantity'].median()
# Out:
# (2.1795130184661864, 1.791759469228055)

# %% [markdown]
# ### Standardization

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 1    536365     71053                  WHITE METAL LANTERN       #6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER        8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.        6
#
#    UnitPrice         Country
# 0       2.55  United Kingdom
# 1       3.39  United Kingdom
# 2       4.23  United Kingdom
# 3       5.07  United Kingdom
# 4       5.91  United Kingdom

# %%
def standard(x):
    n = (x-df["UnitPrice"].mean())/(df["UnitPrice"].std())
    return n
df["UnitPrice"].apply(standard)
# Out:
# 0     -0.299722
# 1     -0.056319
# 2      0.187085
# 3      0.430488
# 4      0.673892
#          ...
# 229    0.192880
# 230   -0.056319
# 231    0.047997
# 232   -0.609772
# 233   -0.676418
# Name: UnitPrice, Length: 234, dtype: float64

# %%
def standard(x):
    n = (x-df["Quantity"].mean())/(df["Quantity"].std())
    return n
df["Quantity"].apply(standard)
# Out:
# 0     -0.329666
# 1     -0.329666
# 2     -0.291383
# 3     -0.329666
# 4     -0.329666
#          ...
# 229    0.014888
# 230    0.014888
# 231    0.014888
# 232    0.474294
# 233    1.393106
# Name: Quantity, Length: 234, dtype: float64

# %% [markdown]
# ### Concatenate

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice         Country  log_UnitPrice  log_Quantity
# 0       2.55  United Kingdom       0.936093      1.791759
# 1       3.39  United Kingdom       1.220830      1.791759
# 2       4.23  United Kingdom       1.442202      2.079442
# 3       5.07  United Kingdom       1.623341      1.791759
# 4       5.91  United Kingdom       1.776646      1.791759

# %%
#Common column is InvoiceNo

# %%
col1 = df['InvoiceNo']
copl2 = df1['InvoiceNo']

# %%
pd.concat([col1,col2],axis=0,ignore_index=True)
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 542138    581587
# 542139    581587
# 542140    581587
# 542141    581587
# 542142    581587
# Name: InvoiceNo, Length: 542143, dtype: object

# %% [markdown]
# ### Merge

# %%
col1 = df['InvoiceNo']
copl2 = df1['InvoiceNo']

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'UnitPrice',
#        'Country', 'log_UnitPrice', 'log_Quantity'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'CustomerID'], dtype='object')

# %%
pd.merge(col1,col2,on="InvoiceNo",how="outer")
# Out:
#        InvoiceNo
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
# ...          ...
# 545740    581587
# 545741    581587
# 545742    581587
# 545743    581587
# 545744    581587
#
# [545745 rows x 1 columns]

# %%
pd.merge(col1,col2,on="InvoiceNo",how="inner")
# Out:
#      InvoiceNo
# 0       536365
# 1       536365
# 2       536365
# 3       536365
# 4       536365
# ...        ...
# 4062    536390
# 4063    536390
# 4064    536390
# 4065    536390
# 4066    536390
#
# [4067 rows x 1 columns]

# %%
pd.merge(col1,col2,on="InvoiceNo",how="right")
# Out:
#        InvoiceNo
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
# ...          ...
# 545738    581587
# 545739    581587
# 545740    581587
# 545741    581587
# 545742    581587
#
# [545743 rows x 1 columns]

# %%
pd.merge(col1,col2,on="InvoiceNo",how="left")
# Out:
#      InvoiceNo
# 0       536365
# 1       536365
# 2       536365
# 3       536365
# 4       536365
# ...        ...
# 4064    536390
# 4065    536390
# 4066    536390
# 4067    536390
# 4068    536390
#
# [4069 rows x 1 columns]

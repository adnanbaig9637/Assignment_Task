# %% [markdown]
# 1. What are the column names in the Iris dataset?
# 2. How many rows and columns are there in the dataset?
# 3. Can you provide a summary of the dataset, including mean, median, and other statistics for each feature?
# 4. What is the average sepal length?
# 5. what is the largest petal length, and what is its value?
# 6. What is the mean and standard deviation of petal width for the Setosa species?
# 7. Check for missing values in the dataset
# 8. Extract the Species column using loc and iloc method
# 9. Drop sepal Width column
# 10. Get petalwidth 10th value using at and iat

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\User\Downloads\Iris_clean.xlsx")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5          10.2
# 4      5           50.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 160  161            7.7           2.8            6.7           2.0
# 161  162            6.3           2.7            4.9           1.8
# 162  163            7.2           3.6            6.1           2.5
# 163  164            6.5           3.2            5.1           2.0
# 164  165            6.4           2.7            5.3           1.9
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 160             NaN
# 161  Iris-virginica
# 162  Iris-virginica
# 163  Iris-virginica
# 164  Iris-virginica
#
# [165 rows x 6 columns]

# %% [markdown]
# 1. What are the column names in the Iris dataset?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             165 non-null    int64
#  1   SepalLengthCm  161 non-null    float64
#  2   SepalWidthCm   159 non-null    float64
#  3   PetalLengthCm  159 non-null    float64
#  4   PetalWidthCm   165 non-null    float64
#  5   Species        160 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# 2. How many rows and columns are there in the dataset?

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5          10.2
# 4      5           50.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 160  161            7.7           2.8            6.7           2.0
# 161  162            6.3           2.7            4.9           1.8
# 162  163            7.2           3.6            6.1           2.5
# 163  164            6.5           3.2            5.1           2.0
# 164  165            6.4           2.7            5.3           1.9
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 160             NaN
# 161  Iris-virginica
# 162  Iris-virginica
# 163  Iris-virginica
# 164  Iris-virginica
#
# [165 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             165 non-null    int64
#  1   SepalLengthCm  161 non-null    float64
#  2   SepalWidthCm   159 non-null    float64
#  3   PetalLengthCm  159 non-null    float64
#  4   PetalWidthCm   165 non-null    float64
#  5   Species        160 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# 3. Can you provide a summary of the dataset, including mean, median, and other statistics for each feature?

# %%
dff = df.describe()
dff
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  165.000000     161.000000    159.000000     159.000000    165.000000
# mean    83.000000       7.510559      4.713208       4.022642      2.810909
# std     47.775517      11.162995     13.468999       2.052505     12.097722
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     42.000000       5.100000      2.800000       1.600000      0.400000
# 50%     83.000000       5.800000      3.000000       4.500000      1.500000
# 75%    124.000000       6.500000      3.300000       5.150000      1.900000
# max    165.000000     116.300000    130.000000      13.800000    111.100000

# %% [markdown]
# 4. What is the average sepal length?

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5          10.2
# 4      5           50.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 160  161            7.7           2.8            6.7           2.0
# 161  162            6.3           2.7            4.9           1.8
# 162  163            7.2           3.6            6.1           2.5
# 163  164            6.5           3.2            5.1           2.0
# 164  165            6.4           2.7            5.3           1.9
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 160             NaN
# 161  Iris-virginica
# 162  Iris-virginica
# 163  Iris-virginica
# 164  Iris-virginica
#
# [165 rows x 6 columns]

# %%
average_sepallen = df.loc[0:165,'SepalLengthCm']
average_sepallen.mean()                             #average_sepal_lenght
# Out:
# 7.510559006211181

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5          10.2
# 4      5           50.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 160  161            7.7           2.8            6.7           2.0
# 161  162            6.3           2.7            4.9           1.8
# 162  163            7.2           3.6            6.1           2.5
# 163  164            6.5           3.2            5.1           2.0
# 164  165            6.4           2.7            5.3           1.9
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 160             NaN
# 161  Iris-virginica
# 162  Iris-virginica
# 163  Iris-virginica
# 164  Iris-virginica
#
# [165 rows x 6 columns]

# %% [markdown]
# 5. what is the largest petal length, and what is its value?

# %%
largest_petal_length = df.iloc[0:165,3]

# %%
largest_petal_length.max()       #Largest petal lenght value
# Out:
# 13.8

# %% [markdown]
# 6. What is the mean and standard deviation of petal width for the Setosa species?

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5          10.2
# 4      5           50.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 160  161            7.7           2.8            6.7           2.0
# 161  162            6.3           2.7            4.9           1.8
# 162  163            7.2           3.6            6.1           2.5
# 163  164            6.5           3.2            5.1           2.0
# 164  165            6.4           2.7            5.3           1.9
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 160             NaN
# 161  Iris-virginica
# 162  Iris-virginica
# 163  Iris-virginica
# 164  Iris-virginica
#
# [165 rows x 6 columns]

# %%
petal_width = df.iloc[0:165,4]

# %%
petal_width.mean()            #Mean of petal width
# Out:
# 2.810909090909091

# %%
petal_width.std()             #Standard deviation of petal width
# Out:
# 12.097722110632041

# %%
petal_width.median()          #Median of petal width
# Out:
# 1.5

# %% [markdown]
# 7. Check for missing values in the dataset

# %% [markdown]
# 8. Extract the Species column using loc and iloc method

# %%
df.loc[0:165,'Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 160               NaN
# 161    Iris-virginica
# 162    Iris-virginica
# 163    Iris-virginica
# 164    Iris-virginica
# Name: Species, Length: 165, dtype: object

# %%
df.iloc[0:165,5]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 160               NaN
# 161    Iris-virginica
# 162    Iris-virginica
# 163    Iris-virginica
# 164    Iris-virginica
# Name: Species, Length: 165, dtype: object

# %% [markdown]
# 9. Drop sepal Width column

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5          10.2
# 4      5           50.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 160  161            7.7           2.8            6.7           2.0
# 161  162            6.3           2.7            4.9           1.8
# 162  163            7.2           3.6            6.1           2.5
# 163  164            6.5           3.2            5.1           2.0
# 164  165            6.4           2.7            5.3           1.9
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 160             NaN
# 161  Iris-virginica
# 162  Iris-virginica
# 163  Iris-virginica
# 164  Iris-virginica
#
# [165 rows x 6 columns]

# %%
df.drop('SepalWidthCm',axis=1,inplace=True)

# %%
df          #Sepal widht column is dropeed
# Out:
#       Id  SepalLengthCm  PetalLengthCm  PetalWidthCm         Species
# 0      1            5.1            1.4           0.2     Iris-setosa
# 1      2            4.9            1.4           0.2     Iris-setosa
# 2      3            4.7            1.3           0.2     Iris-setosa
# 3      4            4.6            1.5          10.2     Iris-setosa
# 4      5           50.0            1.4           0.2     Iris-setosa
# ..   ...            ...            ...           ...             ...
# 160  161            7.7            6.7           2.0             NaN
# 161  162            6.3            4.9           1.8  Iris-virginica
# 162  163            7.2            6.1           2.5  Iris-virginica
# 163  164            6.5            5.1           2.0  Iris-virginica
# 164  165            6.4            5.3           1.9  Iris-virginica
#
# [165 rows x 5 columns]

# %% [markdown]
# 10. Get petalwidth 10th value using at and iat

# %%
df.at[10,'PetalWidthCm']            #petalwidth 10th value using at
# Out:
# 0.2

# %%
df.iat[10,3]                        #petalwidth 10th value using iat
# Out:
# 0.2

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# ### Importing DataSet

# %%
df = pd.read_excel(r"C:\Users\User\Downloads\Sample_-_Superstore.xls")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### Statistical Measures

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %% [markdown]
# ### Structural Handling

# %%
for i in df.columns:
    print(i,df[i].unique())
    print()
# Out:
# Row ID [   1    2    3 ... 9992 9993 9994]
#
# Order ID ['CA-2016-152156' 'CA-2016-138688' 'US-2015-108966' ... 'CA-2014-110422'
#  'CA-2017-121258' 'CA-2017-119914']
#
# Order Date <DatetimeArray>
# ['2016-11-08 00:00:00', '2016-06-12 00:00:00', '2015-10-11 00:00:00',
#  '2014-06-09 00:00:00', '2017-04-15 00:00:00', '2016-12-05 00:00:00',
#  '2015-11-22 00:00:00', '2014-11-11 00:00:00', '2014-05-13 00:00:00',
#  '2014-08-27 00:00:00',
#  ...
#  '2016-10-11 00:00:00', '2014-06-18 00:00:00', '2017-02-28 00:00:00',
#  '2015-05-09 00:00:00', '2014-11-06 00:00:00', '2015-12-29 00:00:00',
#  '2014-04-03 00:00:00', '2016-06-03 00:00:00', '2015-04-12 00:00:00',
#  '2014-01-21 00:00:00']
# Length: 1237, dtype: datetime64[ns]
#
# Ship Date <DatetimeArray>
# ['2016-11-11 00:00:00', '2016-06-16 00:00:00', '2015-10-18 00:00:00',
#  '2014-06-14 00:00:00', '2017-04-20 00:00:00', '2016-12-10 00:00:00',
#  '2015-11-26 00:00:00', '2014-11-18 00:00:00', '2014-05-15 00:00:00',
# ...

# %%
# There is no structural error in data so , we dont need to handle it

# %% [markdown]
# ### Handling with Missing Value

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# There is no missing values in data , so we dont need to handle it.

# %% [markdown]
# ### Handling with duplicates Values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# There is no Duplicated values in data , so we dont need to handle it

# %% [markdown]
# ### Type Casting

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df['Quantity'] = df['Quantity'].astype('int32')

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int32
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# ### Data Visulazation
# ### Univariate Analysis
# ### 1. Histogram

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df['Postal Code'].plot(kind='hist',
                     color='pink',
                     figsize=(8,5),
                     title='Histogram of postal Code',
                     xlabel='Postal Code'
                    
                    
                    
                    )
# Out:
# <Axes: title={'center': 'Histogram of postal Code'}, xlabel='Postal Code', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion
# * There is near about 2600 Customers which is having postal code between 80000-100000
# * There is near about 250 Customers which is having postal code between 5000-6000
# * There is high frequency of customer in between 80000-100000 postal code

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df['Sales'].plot(kind='hist',
                     color='blue',
                     figsize=(8,5),
                     title='Histogram of Sales',
                     xlabel='Sales')
# Out:
# <Axes: title={'center': 'Histogram of Sales'}, xlabel='Sales', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion-
# * There is approx customers which buys the product worth 0-2500 USD
# * There is approx only 200 customers which buys the products worth 2500-5000 USD
# * There is maximum customers which are like to buy products under 2500 USD

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df['Quantity'].plot(kind='hist',
                     color='yellow',
                     figsize=(8,5),
                     title='Histogram of Quantity',
                     xlabel='Quantity')
# Out:
# <Axes: title={'center': 'Histogram of Quantity'}, xlabel='Quantity', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion
# * There is maximum customers near about 3300 customers they are buying 1-2 products from our store
# * There is minimum customers near about 100 customers they are buying 11-12 products from our store
# * We have maximum number of customers they buy 1-2 products

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df['Discount'].plot(kind='hist',
                     color='purple',
                     figsize=(8,5),
                     title='Histogram of Discount',
                     xlabel='Discount in %')
# Out:
# <Axes: title={'center': 'Histogram of Discount'}, xlabel='Discount in %', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion
# * There is maximum number of customers which they are not getting discounts , we should give more discount to almost every customer to grow our buisness .
# * There is only 100 customers they are getting discounts of 0.4%

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df['Profit'].plot(kind='hist',
                     color='#42f5ef',
                     figsize=(8,5),
                     title='Histogram of Profit',
                     xlabel='Profit')
# Out:
# <Axes: title={'center': 'Histogram of Profit'}, xlabel='Profit', ylabel='Frequency'>

# %%
#### Conclusion
* We are almost from all customer getting profit of 0-1000 USD
* There is minimal negative profit
* There is minimal customer from we are getting profit like 2000,4000 USD

# %% [markdown]
# #### Histogram and Density Plot combine with Seaborn

# %%
df['Quantity'].plot(kind='kde',
                    figsize=(8,5),
                    color = 'grey')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(df['Quantity'],color='pink')
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.distplot(df['Discount'])
# Out:
# <Axes: xlabel='Discount', ylabel='Density'>

# %%
sns.distplot(df['Profit'])
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %% [markdown]
# ### Box Plot

# %%
df['Quantity'].plot(kind='box',
                    figsize=(8,5),
                    ylabel = 'Quantity of products')
# Out:
# <Axes: ylabel='Quantity of products'>

# %% [markdown]
# #### Conclusion
# * There is outliers in quanity columns but it will not affect to my data because its a true value product purchased by customers
# * The data is not normally distributed because median in not in middle AND Viscors distance is different

# %%
df['Discount'].plot(kind='box',
                    figsize=(8,5),
                    ylabel = 'Dicsount in %')
# Out:
# <Axes: ylabel='Dicsount in %'>

# %%
df['Profit'].plot(kind='box',
                    figsize=(8,5),
                    ylabel = 'Profit in USD')
# Out:
# <Axes: ylabel='Profit in USD'>

# %% [markdown]
# ### Categrical Data
# ### Count Plot

# %%
sns.countplot(data=df,x='Ship Mode',color='pink',legend=True,width=0.5)
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# #### Conclusion
# * There is approx 6000 customer they got standard class ship mode
# * There is approx 500 customers they got ship mode as same day

# %%
sns.countplot(data=df,x='Segment',color='blue',legend=True,width=0.4)
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %% [markdown]
# #### Conclusion
# * We have near about 5200 customers from consumer segment
# * we have near about 3000 customer from corporate segment
# * We have near about 1800 customer from home office
# * we have segment count in descending order

# %%
sns.countplot(data=df,x='Country',color='yellow',legend=True,width=0.1)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %% [markdown]
# * We have all customers from US only

# %%
sns.countplot(data=df,x='Region',color='red',legend=True,width=0.5)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %% [markdown]
# * Most of our customer from west region near about 3300 customer
# * Lowest of our customer from south region near about 1600 customer

# %%
sns.countplot(data=df,x='Category',color='#42f5aa',legend=True,width=0.4)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# * We are selling most of office supplies products

# %% [markdown]
# ### Pie Chart

# %%
(df['Ship Mode'].value_counts()/len(df['Ship Mode'])*100).plot(kind='pie',autopct="%1.1f" + "Percent",ylabel='Ship Mode')
# Out:
# <Axes: ylabel='Ship Mode'>

# %% [markdown]
# * We have 59.7% standard class shipping
# * We have 19% of second class shipping
# * We have 15.4% of first class shipping
# * We have 5.4% of same day shipping

# %%
(df['Category'].value_counts()/len(df['Category'])*100).plot(kind='pie',autopct="%1.1f"+"Percent")
# Out:
# <Axes: ylabel='count'>

# %%
(df['Sub-Category'].value_counts()/len(df['Sub-Category'])*100).plot(kind='pie',autopct="%1.1f"+"Percent")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Bar plot for categrical data

# %%
df['Sub-Category'].value_counts().plot(kind='barh',
                               color = 'blue',
                               grid = True,
                               width = 0.8,
                               title = 'Bar Plot for Sub Category of Products',
                               figsize=(8,5),
                               ylabel='Category Of products')
# Out:
# <Axes: title={'center': 'Bar Plot for Sub Category of Products'}, ylabel='Category Of products'>

# %% [markdown]
# ### BiVariate Analysis
# ### Categrical & Categrical

# %% [markdown]
# ### Count Plot

# %%
sns.countplot(data=df,x='Ship Mode',hue='Segment')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# #### Conclusion
# * Second Class :-
#     * We have near abput 1000  consumer customer getting  second class shipment
#     * We have near bout 600 corporate customers gettoing second class shipment
#     * We have near about 300 Home office customer getting second class shipment
# * Standrad Class:-
#     * We have near abput 3100  consumer customer getting  standard class shipment
#     * We have near bout 1800 corporate customers gettoing standard class shipment
#     * We have near about 1100 Home office customer getting standard class shipment
# * First Class:-
#     * We have near abput 750  consumer customer getting  First class shipment
#     * We have near bout 500 corporate customers gettoing First class shipment
#     * We have near about 300 Home office customer getting First class shipment
# * Same Day :-
#      * We have near abput 350  consumer customer getting  same day class shipment
#     * We have near bout 200 corporate customers gettoing same day class shipment
#     * We have near about 200 Home office customer getting same day class shipment

# %%
sns.countplot(data=df,x='Region',hue='Category')
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %% [markdown]
# ### Line Chart

# %%
df['Order Date'].plot(kind='line')
# Out:
# <Axes: >

# %%
df['Ship Date'].plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# ### Scatter Plot

# %%
df.plot('Profit','Discount',kind='scatter',grid=True)
# Out:
# <Axes: xlabel='Profit', ylabel='Discount'>

# %% [markdown]
# * Direction is negative
# * strenghth is strong

# %%
df.plot('Quantity','Sales',kind='scatter',grid=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
df.corr(numeric_only=True)
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ### Multivariate Analysis
# ### Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * Correaltion ranges from -0.2 to +1
# * -0.2 to 0.5 indicates negative correlation
# * +0.5 to 0.1 indicates positive correlation

# %%
sns.pairplot(df)

# %% [markdown]
# * Pair plot is for Numeric data only
# * Pair plot is the combination od histogram and scatter plot in single plot

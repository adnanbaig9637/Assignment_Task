# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\car_df_EDA.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0             0           1  alfa-romero       gas        std          two
# 1             1           2  alfa-romero       gas        std          two
# 2             2           3  alfa-romero       gas        std          two
# 3             3           4         audi       gas        std         four
# 4             4           5         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_type  \
# 0  convertible          rwd           front        88.6  ...         dohc
# 1  convertible          rwd           front        88.6  ...         dohc
# 2    hatchback          rwd           front        94.5  ...         ohcv
# 3        sedan          fwd           front        99.8  ...          ohc
# 4        sedan          4wd           front        99.4  ...          ohc
#
# ...

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)   #Dropping Unwanted Columns

# %%
df.head()
# Out:
#           make fuel_type aspiration num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine_location  wheel_base  length  width  ...  engine_type  \
# 0           front        88.6   168.8   64.1  ...         dohc
# 1           front        88.6   168.8   64.1  ...         dohc
# 2           front        94.5   171.2   65.5  ...         ohcv
# 3           front        99.8   176.6   66.2  ...          ohc
# 4           front        99.4   176.6   66.4  ...          ohc
#
#    num_of_cylinders engine_size fuel_system  compression_ratio horsepower  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               208 non-null    object
#  1   fuel_type          208 non-null    object
#  2   aspiration         208 non-null    object
#  3   num_of_doors       208 non-null    object
#  4   body_style         208 non-null    object
#  5   drive_wheels       208 non-null    object
#  6   engine_location    208 non-null    object
#  7   wheel_base         206 non-null    float64
#  8   length             208 non-null    float64
#  9   width              208 non-null    float64
#  10  height             208 non-null    float64
#  11  curb_weight        208 non-null    int64
#  12  engine_type        207 non-null    object
#  13  num_of_cylinders   208 non-null    object
#  14  engine_size        206 non-null    float64
#  15  fuel_system        208 non-null    object
# ...

# %% [markdown]
# ### Statistical Measure

# %%
df.describe()
# Out:
#        wheel_base      length       width      height  curb_weight  \
# count  206.000000  208.000000  208.000000  208.000000   208.000000
# mean    98.919903  174.262019   65.950962   53.750481  2563.375000
# std      6.121266   12.373790    2.159419    2.435010   521.034018
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.675000   64.100000   52.000000  2163.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2422.500000
# 75%    102.400000  183.775000   66.900000   55.500000  2959.250000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        engine_size  compression_ratio    city_mpg  highway_mpg
# count   206.000000         208.000000  208.000000   208.000000
# mean    127.543689          10.194808   25.158654    30.668269
# std      41.599197           4.044135    6.528187     6.873639
# min      61.000000           7.000000   13.000000    16.000000
# ...

# %% [markdown]
# ### Handling Structural Errors

# %%
df.head()
# Out:
#           make fuel_type aspiration num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine_location  wheel_base  length  width  ...  engine_type  \
# 0           front        88.6   168.8   64.1  ...         dohc
# 1           front        88.6   168.8   64.1  ...         dohc
# 2           front        94.5   171.2   65.5  ...         ohcv
# 3           front        99.8   176.6   66.2  ...          ohc
# 4           front        99.4   176.6   66.4  ...          ohc
#
#    num_of_cylinders engine_size fuel_system  compression_ratio horsepower  \
# ...

# %%
for i in df.columns:
    print(i,df[i].unique())
    print()
# Out:
# make ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
# fuel_type ['gas' 'diesel']
#
# aspiration ['std' 'turbo']
#
# num_of_doors ['two' 'four' '?']
#
# body_style ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
# drive_wheels ['rwd' 'fwd' '4wd']
#
# engine_location ['front' 'rear']
#
# wheel_base [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2   nan 103.5 110.   88.4  93.7
#  103.3  95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9
#  106.7 115.6  96.6 120.9 112.  102.7  93.   96.3  95.1  97.2 100.4  91.3
#   99.2 107.9 114.2 108.   89.5  98.4  96.1  99.1  93.3  97.   96.9  95.7
#  102.4 102.9 104.5  97.3 104.3 109.1]
#
# length [168.8 171.2 176.6 177.3 192.7 178.2 176.8 189.  193.8 197.  141.1 155.9
#  158.8 157.3 174.6 173.2 144.6 150.  163.4 157.1 167.5 175.4 169.1 170.7
# ...

# %%
df['make'].dtype,df['make'].unique()
# Out:
# (dtype('O'),
#  array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#         'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#         'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#         'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object))

# %%
df['fuel_type'].dtype,df['fuel_type'].unique()
# Out:
# (dtype('O'), array(['gas', 'diesel'], dtype=object))

# %%
df['aspiration'].dtype,df['aspiration'].unique()
# Out:
# (dtype('O'), array(['std', 'turbo'], dtype=object))

# %%
df['num_of_doors'].dtype,df['num_of_doors'].unique()      #Here we found Structural Error, lets handle it
# Out:
# (dtype('O'), array(['two', 'four', '?'], dtype=object))

# %%
def door(n):
    if n=='two':
        return 2
    elif n== 'four':
        return 4
    else:
        return np.nan

# %%
df['num_of_doors'] = df['num_of_doors'].apply(door)

# %%
df['num_of_doors']
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      4.0
# 4      4.0
#       ...
# 203    4.0
# 204    4.0
# 205    4.0
# 206    4.0
# 207    4.0
# Name: num_of_doors, Length: 208, dtype: float64

# %%
df['num_of_doors'].dtype,df['num_of_doors'].unique()      #we succesfully handled the structural error for num_of_doors column
# Out:
# (dtype('float64'), array([ 2.,  4., nan]))

# %%
df['body_style'].dtype,df['body_style'].unique()
# Out:
# (dtype('O'),
#  array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#        dtype=object))

# %%
df['drive_wheels'].dtype,df['drive_wheels'].unique()
# Out:
# (dtype('O'), array(['rwd', 'fwd', '4wd'], dtype=object))

# %%
df['engine_location'].dtype,df['engine_location'].unique()
# Out:
# (dtype('O'), array(['front', 'rear'], dtype=object))

# %%
df['wheel_base'].dtype,df['wheel_base'].unique()
# Out:
# (dtype('float64'),
#  array([ 88.6,  94.5,  99.8,  99.4, 105.8,  99.5, 101.2,   nan, 103.5,
#         110. ,  88.4,  93.7, 103.3,  95.9,  86.6,  96.5,  94.3,  96. ,
#         113. , 102. ,  93.1,  95.3,  98.8, 104.9, 106.7, 115.6,  96.6,
#         120.9, 112. , 102.7,  93. ,  96.3,  95.1,  97.2, 100.4,  91.3,
#          99.2, 107.9, 114.2, 108. ,  89.5,  98.4,  96.1,  99.1,  93.3,
#          97. ,  96.9,  95.7, 102.4, 102.9, 104.5,  97.3, 104.3, 109.1]))

# %%
df['length'].dtype,df['length'].unique()
# Out:
# (dtype('float64'),
#  array([168.8, 171.2, 176.6, 177.3, 192.7, 178.2, 176.8, 189. , 193.8,
#         197. , 141.1, 155.9, 158.8, 157.3, 174.6, 173.2, 144.6, 150. ,
#         163.4, 157.1, 167.5, 175.4, 169.1, 170.7, 172.6, 199.6, 191.7,
#         159.1, 166.8, 169. , 177.8, 175. , 190.9, 187.5, 202.6, 180.3,
#         208.1, 199.2, 178.4, 173. , 172.4, 165.3, 170.2, 165.6, 162.4,
#         173.4, 181.7, 184.6, 178.5, 186.7, 198.9, 167.3, 168.9, 175.7,
#         181.5, 186.6, 156.9, 157.9, 172. , 173.5, 173.6, 158.7, 169.7,
#         166.3, 168.7, 176.2, 175.6, 183.5, 187.8, 171.7, 159.3, 165.7,
#         180.2, 183.1, 188.8]))

# %%
df['width'].dtype,df['width'].unique()
# Out:
# (dtype('float64'),
#  array([64.1, 65.5, 66.2, 66.4, 66.3, 71.4, 67.9, 64.8, 66.9, 70.9, 60.3,
#         63.6, 63.8, 64.6, 63.9, 64. , 65.2, 62.5, 66. , 61.8, 69.6, 70.6,
#         64.2, 65.7, 66.5, 66.1, 70.3, 71.7, 70.5, 72. , 68. , 64.4, 65.4,
#         68.4, 68.3, 65. , 72.3, 66.6, 63.4, 65.6, 67.7, 67.2, 68.9, 68.8]))

# %%
df['engine_type'].dtype,df['engine_type'].unique()
# Out:
# (dtype('O'),
#  array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', nan, 'ohcf', 'dohcv'],
#        dtype=object))

# %%
df['num_of_cylinders'].dtype,df['num_of_cylinders'].unique()     #Lets make it Numerical
# Out:
# (dtype('O'),
#  array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#        dtype=object))

# %%
def cyl(n):
    if n== 'two' :
        return 2
    elif n== 'three' :
        return 3
    elif n== 'four' :
        return 4
    elif n== 'six' :
        return 6
    elif n== 'eight' :
        return 8
    elif n== 'five' :
        return 5
    else:
        return 12

# %%
df['num_of_cylinders'] = df['num_of_cylinders'].apply(cyl)

# %%
df['num_of_cylinders'].dtype,df['num_of_cylinders'].unique()
# Out:
# (dtype('int64'), array([ 4,  6,  5,  3, 12,  2,  8], dtype=int64))

# %%
df['engine_size'].dtype,df['engine_size'].unique()
# Out:
# (dtype('float64'),
#  array([130., 152., 109., 136., 131., 108., 164., 209.,  61.,  90.,  98.,
#         122., 156.,  92.,  79., 110.,  nan, 111., 119., 258., 326.,  91.,
#          70.,  80., 140., 134., 183., 234., 308., 304.,  97., 103., 120.,
#         181., 151., 194., 203., 132., 121., 146., 171., 161., 141., 173.,
#         145.]))

# %%
df['fuel_system'].dtype,df['fuel_system'].unique()
# Out:
# (dtype('O'),
#  array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#        dtype=object))

# %%
df['compression_ratio'].dtype,df['compression_ratio'].unique()
# Out:
# (dtype('float64'),
#  array([ 9.  , 10.  ,  8.  ,  8.5 ,  8.3 ,  7.  ,  8.8 ,  9.5 ,  9.6 ,
#          9.41,  9.4 ,  7.6 ,  9.2 , 10.1 ,  9.1 ,  8.1 , 11.5 ,  8.6 ,
#         22.7 , 22.  , 21.5 ,  7.5 , 21.9 ,  7.8 ,  8.4 , 21.  ,  8.7 ,
#          9.31,  9.3 ,  7.7 , 22.5 , 23.  ]))

# %%
df['horsepower'].dtype,df['horsepower'].unique()
# Out:
# (dtype('O'),
#  array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#         '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#         '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#         '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#         '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#         '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#         '106'], dtype=object))

# %%
df[~df['horsepower'].str.isnumeric()]
# Out:
#         make fuel_type aspiration  num_of_doors body_style drive_wheels  \
# 130  renault       gas        std           4.0      wagon          fwd
# 131  renault       gas        std           2.0  hatchback          fwd
#
#     engine_location  wheel_base  length  width  ...  engine_type  \
# 130           front        96.1   181.5   66.5  ...          ohc
# 131           front        96.1   176.8   66.6  ...          ohc
#
#      num_of_cylinders engine_size  fuel_system  compression_ratio horsepower  \
# 130                 4       132.0         mpfi                8.7          ?
# 131                 4       132.0         mpfi                8.7          ?
#
#      peak_rpm city_mpg highway_mpg  price
# 130         ?       23          31   9295
# 131         ?       23          31   9895
#
# [2 rows x 22 columns]

# %%
df['horsepower']= df['horsepower'].replace('?',np.nan)

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', nan, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['peak_rpm'].dtype,df['peak_rpm'].unique()
# Out:
# (dtype('O'),
#  array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#         '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#         '5900', '5750', '?', '5250', '4900', '4400', '6600', '5300'],
#        dtype=object))

# %%
df['peak_rpm']= df['peak_rpm'].replace('?',np.nan)

# %%
df['peak_rpm'].dtype,df['peak_rpm'].unique()
# Out:
# (dtype('O'),
#  array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#         '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#         '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#        dtype=object))

# %%
df['city_mpg'].dtype,df['city_mpg'].unique()
# Out:
# (dtype('int64'),
#  array([21, 19, 24, 18, 17, 16, 23, 20, 15, 47, 38, 37, 31, 49, 30, 27, 25,
#         13, 26, 36, 22, 14, 45, 28, 32, 35, 34, 29, 33], dtype=int64))

# %%
df['highway_mpg'].dtype,df['highway_mpg'].unique()
# Out:
# (dtype('int64'),
#  array([27, 26, 30, 22, 25, 20, 29, 28, 53, 43, 41, 38, 24, 54, 42, 34, 33,
#         31, 19, 17, 23, 32, 39, 18, 16, 37, 50, 36, 47, 46], dtype=int64))

# %%
df['price'].dtype,df['price'].unique()
# Out:
# (dtype('O'),
#  array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#         '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#         '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#         '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#         '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#         '12945', '10345', '6785', '11048', nan, '35550', '36000', '5195',
#         '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#         '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#         '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#         '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#         '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#         '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#         '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df['price']= df['price'].replace('?',np.nan)

# %%
df['price'].dtype,df['price'].unique()
# Out:
# (dtype('O'),
#  array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#         '23875', nan, '16430', '16925', '20970', '21105', '24565', '30760',
#         '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#         '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#         '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#         '12945', '10345', '6785', '11048', '35550', '36000', '5195',
#         '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#         '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#         '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#         '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#         '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#         '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#         '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
#Now we have succesfully handled all structural error for all columns
#We can also do this with for loop in that all will be column will be itirate

# %% [markdown]
# ### Handle the missing Values

# %%
df.isna().sum()             #These are missing values
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         2
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           2
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          2
# fuel_system          0
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                8
# dtype: int64

# %%
df['wheel_base'].fillna(df['wheel_base'].median(),inplace=True)

# %%
df['num_of_doors'].fillna(df['num_of_doors'].median(),inplace=True)

# %%
df['engine_type'].fillna(df['engine_type'].mode()[0],inplace=True)

# %%
df['engine_size'].fillna(df['engine_size'].median(),inplace=True)

# %%
df['horsepower'].fillna(df['horsepower'].median(),inplace=True)

# %%
df['peak_rpm'].fillna(df['peak_rpm'].median(),inplace=True)

# %%
df['price'].fillna(df['price'].median(),inplace=True)

# %%
df.isna().sum()           #We filled all the missing Values Categrical data with mode(), Numerical With Mean()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### Handling With duplicat values

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df[df.duplicated()]
# Out:
#       make fuel_type aspiration  num_of_doors body_style drive_wheels  \
# 205  volvo       gas        std           4.0      sedan          rwd
# 206  volvo    diesel      turbo           4.0      sedan          rwd
# 207  volvo       gas      turbo           4.0      sedan          rwd
#
#     engine_location  wheel_base  length  width  ...  engine_type  \
# 205           front       109.1   188.8   68.9  ...         ohcv
# 206           front       109.1   188.8   68.9  ...          ohc
# 207           front       109.1   188.8   68.9  ...          ohc
#
#      num_of_cylinders engine_size  fuel_system  compression_ratio horsepower  \
# 205                 6       173.0         mpfi                8.8        134
# 206                 6       145.0          idi               23.0        106
# 207                 4       141.0         mpfi                9.5        114
#
#      peak_rpm city_mpg highway_mpg    price
# 205      5500       18          23    21485
# ...

# %%
df.drop_duplicates(keep = 'first',inplace=True)

# %%
df.duplicated().sum()       #We successfully dropped the duplicate values
# Out:
# 0

# %% [markdown]
# ### Handling With TypeCasting

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors         float64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders       int64
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                 object
# dtype: object

# %%
df["price"] = df["price"].astype("float64")

# %%
df["peak_rpm"] = df["peak_rpm"].astype("float64")

# %%
df["horsepower"] = df["horsepower"].astype("float64")

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors         float64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders       int64
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
df.head()
# Out:
#           make fuel_type aspiration  num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std           2.0  convertible          rwd
# 1  alfa-romero       gas        std           2.0  convertible          rwd
# 2  alfa-romero       gas        std           2.0    hatchback          rwd
# 3         audi       gas        std           4.0        sedan          fwd
# 4         audi       gas        std           4.0        sedan          4wd
#
#   engine_location  wheel_base  length  width  ...  engine_type  \
# 0           front        88.6   168.8   64.1  ...         dohc
# 1           front        88.6   168.8   64.1  ...         dohc
# 2           front        94.5   171.2   65.5  ...         ohcv
# 3           front        99.8   176.6   66.2  ...          ohc
# 4           front        99.4   176.6   66.4  ...          ohc
#
#    num_of_cylinders engine_size  fuel_system  compression_ratio horsepower  \
# ...

# %% [markdown]
# ### Data Visulaization--Univariate Analysis--

# %% [markdown]
# ### Histogram for numerical data

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["num_of_doors"].plot(kind="hist",xlabel="No of Car Doors",title = "Histogram of No of Car Doors")
# Out:
# <Axes: title={'center': 'Histogram of No of Car Doors'}, xlabel='No of Car Doors', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion for " Histogram of No of Car Doors"
# * There is highest number/frequency of cars having 4 doors.
# * There is approximately 115 cars having 4 doors.
# * There is lowest number/frequency of cars having 2 doors as compare to 4 doors.
# * There is approximately 90 cars having 2 doors.

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['price'].plot(kind='hist',xlabel='Prices',title='Histogram of Car Prices',color='purple')
# Out:
# <Axes: title={'center': 'Histogram of Car Prices'}, xlabel='Prices', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion for " Histogram of Price Of Cars"
# * There is higest numbers/frequency of cars which has price between 5000-10000,USD
# * There is approximately 80 cars having price between 5000-10000 USD
# * There is Lowest number/frequency of cars which has price between 40000-45000,USD
# * There is approximately 2/3 cars having price between 40000-45000 USD
# * We can say maximum numbers of cars price in range between 5000-15000

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
out["wheel_base"].plot(kind="hist",xlabel="Wheel Base",title = "Histogram of Wheel Base")
# Out:
# <Axes: title={'center': 'Histogram of Wheel Base'}, xlabel='Wheel Base', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion for " Histogram of Wheel base of cars"
# * There is highest number/frequency of cars which having wheel base between 93-100
# * There is approx 120 cars having wheel base in between 93-100
# * There is lowest numbers/frequency of cars which having wheel base between 85-95
# * There is approx only 2 cars having wheelbase in between 85-95

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
out["highway_mpg"].plot(kind="hist",xlabel="highway_mpg",title = "Histogram of Highway mpg")
# Out:
# <Axes: title={'center': 'Histogram of Highway mpg'}, xlabel='highway_mpg', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion for " Histogram of Highway_mpg"
# * There is highest numbers of cars which is having highway mileage in between 43-48 mpg
# * There is approx 53 cars which having highway mileage in between 43-48 mpg
# * There is lowest numbers of cars which is having highway mileage in between 48-52 mpg
# * There is approx 2 cars which having highway mileage in between 48-52 mpg
# * There is maximum cars having highway mileage between 20-48

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["num_of_cylinders"].plot(kind="hist"
                            ,xlabel="num_of_cylinders",
                            title = "Histogram of num_of_cylinders",
                            figsize=(8,6),
                            color='pink')
# Out:
# <Axes: title={'center': 'Histogram of num_of_cylinders'}, xlabel='num_of_cylinders', ylabel='Frequency'>

# %% [markdown]
# #### Conclusion for " Histogram of Num of Cylinders in cars"
# * There is highest number of cars which is having 4 cylinder.
# * There is approx 160 cars having 4 cylinders
# * There is lowest number cars which is having 3 and 12 cylinder.
# * There us approx only 2 cars having 3 and 12 cylinder

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["length"].plot(kind="hist",
                  xlabel="length of vahicle",
                  title = "Histogram of length of vehicle",
                  figsize=(8,6))
# Out:
# <Axes: title={'center': 'Histogram of length of vehicle'}, xlabel='length of vahicle', ylabel='Frequency'>

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["width"].plot(kind="hist",
                  xlabel="width of vahicle",
                  title = "Histogram of width of vehicle",
                  figsize=(8,6))
# Out:
# <Axes: title={'center': 'Histogram of width of vehicle'}, xlabel='width of vahicle', ylabel='Frequency'>

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["engine_size"].plot(kind="hist",
                  xlabel="engine_size",
                  color = '#f542cb',
                  title = "Histogram of engine size of vehicle",
                  figsize=(8,6),
                  )
# Out:
# <Axes: title={'center': 'Histogram of engine size of vehicle'}, xlabel='engine_size', ylabel='Frequency'>

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["compression_ratio"].plot(kind="hist",
                  xlabel="compression_ratio",
                  color = '#bf42f5',
                  title = "Histogram of compression ratio of vehicle",
                  figsize=(8,6),
                  )
# Out:
# <Axes: title={'center': 'Histogram of compression ratio of vehicle'}, xlabel='compression_ratio', ylabel='Frequency'>

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["horsepower"].plot(kind="hist",
                  xlabel="horsepower",
                  color = '#4e42f5',
                  title = "Histogram of horsepower of vehicle",
                  figsize=(8,6),
                  )
# Out:
# <Axes: title={'center': 'Histogram of horsepower of vehicle'}, xlabel='horsepower', ylabel='Frequency'>

# %%
plt.style.use("ggplot")
plt.style.use("dark_background")
df["peak_rpm"].plot(kind="hist",
                  xlabel="peak_rpm",
                  color = '#42bcf5',
                  title = "Histogram of peak_rpm of vehicles",
                  figsize=(8,6),
                  )
# Out:
# <Axes: title={'center': 'Histogram of peak_rpm of vehicles'}, xlabel='peak_rpm', ylabel='Frequency'>

# %% [markdown]
# ### Density Plot for numericals data

# %%
df['num_of_doors'].plot(kind='kde',
                        color = 'yellow',
                        title = 'Density Plot for Numbers of Doors of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for Numbers of Doors of Cars'}, ylabel='Density'>

# %% [markdown]
# #### Conclusion for " Density Plot of Num of doors in cars"
# * We can see in Density Plot There is hike at 2 doors and 4 door
# * The cars which have 4 doors has density about 0.65
# * The cars which have 2 doors has density about 0.5
# * Also there is perfect curve we can say its normally distributed

# %%
df['wheel_base'].plot(kind='kde',
                        color = 'green',
                        title = 'Density Plot for wheel_base of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for wheel_base of Cars'}, ylabel='Density'>

# %% [markdown]
# #### Conclusion for "Density plot of wheel base of cars"
# * There is hike in density approx 0.09 when the cars having wheel base of 95

# %%
df['num_of_cylinders'].plot(kind='kde',
                        color = 'grey',
                        title = 'Density Plot for num_of_cylinders in Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for num_of_cylinders in Cars'}, ylabel='Density'>

# %% [markdown]
# #### Conclusion for "Density plot for numnber of cylinders in cars"
# * There is approx 0.8 density for the cars having 4 cylinders which is highest density.
# * There is approx 0.02 density for the cars having 12 cylinders which us lowest density.

# %%
df['length'].plot(kind='kde',
                        color = 'blue',
                        title = 'Density Plot for length of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for length of Cars'}, ylabel='Density'>

# %%
df['width'].plot(kind='kde',
                        color = 'pink',
                        title = 'Density Plot for width of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for width of Cars'}, ylabel='Density'>

# %%
plt.style.use('classic')
plt.style.use('dark_background')
df['engine_size'].plot(kind='kde',
                        color = 'pink',
                        title = 'Density Plot for engine size of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for engine size of Cars'}, ylabel='Density'>

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['compression_ratio'].plot(kind='kde',
                        color = 'green',
                        title = 'Density Plot for compression ratio Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for compression ratio Cars'}, ylabel='Density'>

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['horsepower'].plot(kind='kde',
                        color = 'green',
                        title = 'Density Plot for horsepower of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for horsepower of Cars'}, ylabel='Density'>

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['peak_rpm'].plot(kind='kde',
                        color = 'green',
                        title = 'Density Plot for peak rpm of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for peak rpm of Cars'}, ylabel='Density'>

# %%
plt.style.use('ggplot')
plt.style.use('dark_background')
df['price'].plot(kind='kde',
                        color = 'green',
                        title = 'Density Plot for price of Cars',
                        figsize=(8,6)
                       
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Density Plot for price of Cars'}, ylabel='Density'>

# %% [markdown]
# #### Conclusin for "Density plot of price of cars"
# * There is highest density of cars which is having price in between 5000-10000USD
# * The density is approx 0.00008
# * There is lowest density of cars which is having price in between 45000-50000USD
# * The density is approx 0.00001

# %% [markdown]
# ### Box Plot for the Numerical data
# **Box Plot is used to check the outliers in data**

# %%
df['num_of_doors'].plot(kind='box',
                        color = 'red',
                        figsize = (8,6),
                        title = 'Box Plot for number of doors of cars',
                        ylabel=' no of doors of cars'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for number of doors of cars'}, ylabel=' no of doors of cars'>

# %% [markdown]
# #### Conclusion for the "Box Plot for number of doors of cars"
# * We can see in Box Plot there is no outliers in data because there is no value greater than upper limit and less than lower limit
# * Lower limit in 2
# * Upper limit is 4

# %%
df['price'].plot(kind='box',
                        color = 'blue',
                        figsize = (8,6),
                        title = 'Box Plot for price of cars',
                        ylabel='price of cars'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for price of cars'}, ylabel='price of cars'>

# %% [markdown]
# #### Conclusion for the "Box Plot for number of doors of cars"
# * There is outliers in data because there is values more than upper limit But it will not affect to my conclusion because it is true values PRICE OF CAR
# * From the BoxViscor we can say the data is not normally ditributed because there is differnce between upper viscor and lower viscor,and the MEDIAN is also not proper in middle.

# %%
df['wheel_base'].plot(kind='box',
                        color = 'yellow',
                        figsize = (8,6),
                        title = 'Box Plot for wheel_base of cars',
                        ylabel='wheel base  value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for wheel_base of cars'}, ylabel='wheel base  value'>

# %% [markdown]
# #### Conclusion for the "Box Plot for wheel base of cars"
# * There is outliers in data because there is values more than upper limit, upper limit is 112
# * From the BoxViscor we can say the data is  normally ditributed because there is no difference between upper viscor and lower viscor,and the MEDIAN is also proper in middle.

# %%
df['length'].plot(kind='box',
                        color = 'grey',
                        figsize = (8,6),
                        title = 'Box Plot for length of cars',
                        ylabel='length values'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for length of cars'}, ylabel='length values'>

# %%
df['width'].plot(kind='box',
                        color = 'yellow',
                        figsize = (8,6),
                        title = 'Box Plot for width of cars',
                        ylabel='width values'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for width of cars'}, ylabel='width values'>

# %%
df['num_of_cylinders'].plot(kind='box',
                        color = 'yellow',
                        figsize = (8,6),
                        title = 'Box Plot for num_of_cylinders in cars',
                        ylabel='num of cylinders value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for num_of_cylinders in cars'}, ylabel='num of cylinders value'>

# %%
df['engine_size'].plot(kind='box',
                        color = 'red',
                        figsize = (8,6),
                        title = 'Box Plot for engine_size in cars',
                        ylabel='engine_size value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for engine_size in cars'}, ylabel='engine_size value'>

# %%
df['compression_ratio'].plot(kind='box',
                        color = 'blue',
                        figsize = (8,6),
                        title = 'Box Plot for compression_ratio in cars',
                        ylabel='compression_ratio value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for compression_ratio in cars'}, ylabel='compression_ratio value'>

# %%
df['horsepower'].plot(kind='box',
                        color = 'blue',
                        figsize = (8,6),
                        title = 'Box Plot for horsepower in cars',
                        ylabel='horsepower value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for horsepower in cars'}, ylabel='horsepower value'>

# %%
df['peak_rpm'].plot(kind='box',
                        color = 'white',
                        figsize = (8,6),
                        title = 'Box Plot for peak_rpm in cars',
                        ylabel='peak_rpm value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for peak_rpm in cars'}, ylabel='peak_rpm value'>

# %%
df['city_mpg'].plot(kind='box',
                        color = 'green',
                        figsize = (8,6),
                        title = 'Box Plot for city_mpg in cars',
                        ylabel='city mpg value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for city_mpg in cars'}, ylabel='city mpg value'>

# %%
df['highway_mpg'].plot(kind='box',
                        color = 'green',
                        figsize = (8,6),
                        title = 'Box Plot for highway_mpg in cars',
                        ylabel='highway mpg value'
                       
                       
                       
                       )
# Out:
# <Axes: title={'center': 'Box Plot for highway_mpg in cars'}, ylabel='highway mpg value'>

# %% [markdown]
# ###  Categrical Data
# ### Count Plot for categrical data

# %%
sns.countplot(data=df,x='make',
              color='pink',
              width = 0.9)
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %% [markdown]
# #### Conclusion for the count Plot of Make(Company) of Cars
# * There is approx 32 cars which is manufactured by TOYOTA which higest in data
# * There is approx 2/3 cars which is manufactured by alfa-romero which is lowest in data

# %%
sns.countplot(data=df,x='fuel_type',
              color='green',
              width = 0.2
              )
# Out:
# <Axes: xlabel='fuel_type', ylabel='count'>

# %% [markdown]
# #### Conclusion for the count Plot of Make(Company) of Cars
# * The maximum number of cars has fuel type of GAS
# * There is approx 180 cars which is having fuel type of gas
# * There is approx 30 cars which is having fuel type of diesel

# %%
sns.countplot(data=df,x='aspiration',
              color='blue',
              width = 0.2
              )
# Out:
# <Axes: xlabel='aspiration', ylabel='count'>

# %% [markdown]
# #### Conclusion for the count Plot of Make(Company) of Cars
# * The maximum number of cars has aspiration of std(standard)
# There is approx 165 cars which is having aspiration of std(standard)
# There is approx 35 cars which is having aspiration of turbo

# %%
sns.countplot(data=df,x='body_style',
              color='red',
              width = 0.8
              )
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.countplot(data=df,x='drive_wheels',
              color='yellow',
              width = 0.4
              )
# Out:
# <Axes: xlabel='drive_wheels', ylabel='count'>

# %%
sns.countplot(data=df,x='engine_location',
              color='white',
              width = 0.4
              )
# Out:
# <Axes: xlabel='engine_location', ylabel='count'>

# %%
sns.countplot(data=df,x='engine_type',
              color='white',
              width = 0.4
              )
# Out:
# <Axes: xlabel='engine_type', ylabel='count'>

# %%
sns.countplot(data=df,x='fuel_system',
              color='pink',
              width = 0.4
              )
# Out:
# <Axes: xlabel='fuel_system', ylabel='count'>

# %% [markdown]
# ### Bar Plot for Categrical Data

# %%
df['make'].value_counts().plot(kind='bar',
                               color = 'blue',
                               grid = True,
                               width = 0.8,
                               title = 'Bar Plot for Manufacturing Company of Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot for Manufacturing Company of Cars'}, xlabel='make', ylabel='No of Cars'>

# %%
df['make'].value_counts().plot(kind='barh',
                               color = 'blue',
                               grid = True,
                               width = 0.8,
                               title = 'Bar Plot for Manufacturing Company of Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot for Manufacturing Company of Cars'}, ylabel='No of Cars'>

# %%
df['fuel_type'].value_counts().plot(kind='bar',
                               color = ['green','grey'],
                               grid = True,
                               width = 0.4,
                               title = 'Bar Plot for fuel_type of Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot for fuel_type of Cars'}, xlabel='fuel_type', ylabel='No of Cars'>

# %%
df['aspiration'].value_counts().plot(kind='bar',
                               color = ['pink','white'],
                               grid = True,
                               width = 0.4,
                               title = 'Bar Plot for aspiration of Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot for aspiration of Cars'}, xlabel='aspiration', ylabel='No of Cars'>

# %%
df['body_style'].value_counts().plot(kind='bar',
                               color = ['yellow'],
                               grid = True,
                               width = 0.8,
                               title = 'Bar Plot forbody_style of Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot forbody_style of Cars'}, xlabel='body_style', ylabel='No of Cars'>

# %%
df['drive_wheels'].value_counts().plot(kind='bar',
                               color = ['red'],
                               grid = True,
                               width = 0.4,
                               title = 'Bar Plot drive_wheels of Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot drive_wheels of Cars'}, xlabel='drive_wheels', ylabel='No of Cars'>

# %%
df['engine_location'].value_counts().plot(kind='bar',
                               color = ['purple'],
                               grid = True,
                               width = 0.2,
                               title = 'Bar Plot engine_location in Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot engine_location in Cars'}, xlabel='engine_location', ylabel='No of Cars'>

# %%
df['fuel_system'].value_counts().plot(kind='bar',
                               color = ['#42bcf5'],
                               grid = True,
                               width = 0.8,
                               title = 'Bar Plot fuel_system in Cars',
                               figsize=(8,5),
                               ylabel='No of Cars'
                   
                              
                              
                              
                              
                              )
# Out:
# <Axes: title={'center': 'Bar Plot fuel_system in Cars'}, xlabel='fuel_system', ylabel='No of Cars'>

# %% [markdown]
# ### Pie Chart for categrical Data

# %%
(df['make'].value_counts()/len(df['make'])*100).plot(kind='pie',
                               figsize = (25,30),
                               legend = True,
                               autopct = '%1.1f'+'Percent' ,                   
                               ylabel = 'Percentage'                     
                              
                              
                              
                              )
# Out:
# <Axes: ylabel='Percentage'>

# %%
(df['body_style'].value_counts()/len(df['body_style'])*100).plot(kind='pie',
                                                                 ylabel='Percentage',
                                                                 figsize=(15,8),
                                                                 autopct='%1.1f'+' Percent',
                                                                 legend = True,
                                                                 title='Pie chart for Body Style of Cars '
                                                            )
# Out:
# <Axes: title={'center': 'Pie chart for Body Style of Cars '}, ylabel='Percentage'>

# %% [markdown]
# #### Conclusion for Pie Chart of Body Style of cars
# * Highest percentage of cars having body style of SEDAN
# * Lowest percentage of cars having body style of CONVERTIBLE
# * There is 46.8 percent of cars having bodystyle of sedan
# * There is 34.1 percent of cars having bodystyle of hatchback
# * There is 12.2 percent of cars having bodystyle of wagon
# * There is 3.9 percent of cars having bodystyle of hardtop
# * There is 2.9 percent of cars having bodystyle of convertible

# %%
(df['drive_wheels'].value_counts()/len(df['drive_wheels'])*100).plot(kind='pie',
                                                                 ylabel='Percentage',
                                                                 figsize=(10,8),
                                                                 autopct='%1.1f'+' Percent',
                                                                 legend = True,
                                                                 title='Pie chart for drive wheels of Cars ')
# Out:
# <Axes: title={'center': 'Pie chart for drive wheels of Cars '}, ylabel='Percentage'>

# %% [markdown]
# #### Conclusion for Pie Chart of drive wheels of cars
# * Highest percentage of cars having front wheel drive (fwd)
# * Lowest percentage of cars having 4 wheel drive (4wd)
# * There is 58.5 percent of cars having front wheel drive
# * There is 37.1 percent of cars having rear wheel drive
# * There is 4.4 percent of cars having four wheel drive

# %%
(df['fuel_system'].value_counts()/len(df['fuel_system'])*100).plot(kind='pie',
                                                                 ylabel='Percentage',
                                                                 figsize=(10,8),
                                                                 autopct='%1.1f'+' Percent',
                                                                 legend = True,
                                                                 title='Pie chart for fuel system of Cars ')
# Out:
# <Axes: title={'center': 'Pie chart for fuel system of Cars '}, ylabel='Percentage'>

# %% [markdown]
# #### Conclusion for Pie Chart of fuel system in cars
# * Highest percentage of cars having mpfi(MULTI POINT FUEL INJECTION) fuel system
# * Lowest percentage of cars having spfi(SINGLE POINT FUEL INJECTION) fuel system
# * There is 45.9 percent of cars having mpfi(MULTI POINT FUEL INJECTION) fuel system
# * There is only 0.5 percent of cars having spfi(SINGLE POINT FUEL INJECTION) fuel system (fwd)

# %%
(df['fuel_type'].value_counts()/len(df['fuel_type'])*100).plot(kind='pie',
                                                                 ylabel='Percentage',
                                                                 figsize=(10,8),
                                                                 autopct='%1.1f'+' Percent',
                                                                 legend = True,
                                                                 title='Pie chart for fuel type in Cars ')
# Out:
# <Axes: title={'center': 'Pie chart for fuel type in Cars '}, ylabel='Percentage'>

# %% [markdown]
# #### Conclusion for Pie Chart of fuel type in cars
# * Highest percentage of cars having GAS fuel type
# * Lowest percentage of cars having DIESEL fuel type
# * There is 90.2 percent of cars having GAS fuel type
# * There is only 9.8 percent of cars having DIESEL fuel type

# %%
(df['engine_location'].value_counts()/len(df['engine_location'])*100).plot(kind='pie',
                                                                     legend = True,
                                                                     ylabel='Percentage',
                                                                     autopct = '%1.1f'+'Percent',
                                                                     figsize = (10,8),
                                                                     title='Pie chart for Engine Location in Cars '
                                                                    
                                                                    
                                                                    
                                                                    
                                                                    )
# Out:
# <Axes: title={'center': 'Pie chart for Engine Location in Cars '}, ylabel='Percentage'>

# %% [markdown]
# #### Conclusion for Pie Chart of fuel type in cars
# * There is 98.5 percent of cars which is having engine at front
# * There is only 1.5 percent of cars which having engine at rear

# %% [markdown]
# ### Data Visualization Bi-Variate Analysis
# #### Categrical & Categrical
# **CrossTab**

# %%
pd.crosstab(df['make'],df['fuel_type'])
# Out:
# fuel_type      diesel  gas
# make
# alfa-romero         0    3
# audi                0    7
# bmw                 0    8
# chevrolet           0    3
# dodge               0    9
# honda               0   13
# isuzu               0    4
# jaguar              0    3
# mazda               2   15
# mercedes-benz       4    4
# mercury             0    1
# mitsubishi          0   13
# nissan              1   17
# peugot              5    6
# plymouth            0    7
# porsche             0    5
# renault             0    2
# saab                0    6
# subaru              0   12
# toyota              3   29
# volkswagen          4    8
# volvo               1   10

# %%
pd.crosstab(df['aspiration'],df['body_style'])
# Out:
# body_style  convertible  hardtop  hatchback  sedan  wagon
# aspiration
# std                   6        7         57     78     20
# turbo                 0        1         13     18      5

# %%
pd.crosstab(df['drive_wheels'],df['engine_location'])
# Out:
# engine_location  front  rear
# drive_wheels
# 4wd                  9     0
# fwd                120     0
# rwd                 73     3

# %%
pd.crosstab(df['engine_type'],df['fuel_system'])
# Out:
# fuel_system  1bbl  2bbl  4bbl  idi  mfi  mpfi  spdi  spfi
# engine_type
# dohc            0     0     0    0    0    12     0     0
# dohcv           0     0     0    0    0     1     0     0
# l               0     1     0    5    0     6     0     0
# ohc            11    57     0   15    1    54     9     1
# ohcf            0     8     0    0    0     7     0     0
# ohcv            0     0     0    0    0    13     0     0
# rotor           0     0     3    0    0     1     0     0

# %% [markdown]
# **CountPlot**

# %%
sns.countplot(data=df,x='make',hue='fuel_type',width=0.6)
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
sns.countplot(data=df,x='aspiration',hue='body_style')
# Out:
# <Axes: xlabel='aspiration', ylabel='count'>

# %%
sns.countplot(data=df,x='engine_location',hue='drive_wheels',width=0.5)
# Out:
# <Axes: xlabel='engine_location', ylabel='count'>

# %%
sns.countplot(data=df,x='fuel_system',hue='engine_type',width=1)
# Out:
# <Axes: xlabel='fuel_system', ylabel='count'>

# %% [markdown]
# **Stack/Group Bar plot**

# %%
df
# Out:
#             make fuel_type aspiration  num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas        std           2.0  convertible          rwd
# 1    alfa-romero       gas        std           2.0  convertible          rwd
# 2    alfa-romero       gas        std           2.0    hatchback          rwd
# 3           audi       gas        std           4.0        sedan          fwd
# 4           audi       gas        std           4.0        sedan          4wd
# ..           ...       ...        ...           ...          ...          ...
# 200        volvo       gas        std           4.0        sedan          rwd
# 201        volvo       gas      turbo           4.0        sedan          rwd
# 202        volvo       gas        std           4.0        sedan          rwd
# 203        volvo    diesel      turbo           4.0        sedan          rwd
# 204        volvo       gas      turbo           4.0        sedan          rwd
#
# ...

# %%
group=['g1','g2','g3']
male=[21,36,120]
female=[16,18,19]

fig,ax=plt.subplots()
ax.bar(group,male)
ax.bar(group,female,bottom=male)
# Out:
# <BarContainer object of 3 artists>

# %%
ax=plt.subplot()
ax.bar(df['body_style'],df['num_of_doors'])
ax.bar(df['body_style'],df['num_of_cylinders'],bottom=df['num_of_doors'])
# Out:
# <BarContainer object of 205 artists>

# %% [markdown]
# #### Numerical & Numerical
# **Correlation Coefficient**

# %%
df.corr(numeric_only=True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434334  0.385675  0.197735  0.540286
# wheel_base             0.434334    1.000000  0.871674  0.795635  0.586421
# length                 0.385675    0.871674  1.000000  0.841118  0.491029
# width                  0.197735    0.795635  0.841118  1.000000  0.279210
# height                 0.540286    0.586421  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.775265  0.877728  0.867032  0.295572
# num_of_cylinders      -0.019503    0.340349  0.430672  0.545007 -0.013995
# engine_size            0.017968    0.567020  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250870  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.351295  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.364688 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467683 -0.670909 -0.642704 -0.048640
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434334  0.385675  0.197735  0.540286
# wheel_base             0.434334    1.000000  0.871674  0.795635  0.586421
# length                 0.385675    0.871674  1.000000  0.841118  0.491029
# width                  0.197735    0.795635  0.841118  1.000000  0.279210
# height                 0.540286    0.586421  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.775265  0.877728  0.867032  0.295572
# num_of_cylinders      -0.019503    0.340349  0.430672  0.545007 -0.013995
# engine_size            0.017968    0.567020  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250870  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.351295  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.364688 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467683 -0.670909 -0.642704 -0.048640
# ...

# %% [markdown]
# **Scatter PLot**

# %%
df.plot('wheel_base','length',kind='scatter',
                              legend = True,
                              figsize=(10,4),
                              grid=True,
                              title='Scatter Plot between Wheel base and Length of vehicle')
# Out:
# <Axes: title={'center': 'Scatter Plot between Wheel base and Length of vehicle'}, xlabel='wheel_base', ylabel='length'>

# %%
df.plot('engine_size','curb_weight',kind='scatter',
                                    legend = True,
                                    figsize=(10,4),
                                    grid=True,
                                    title='Scatter Plot between engine size and curb weight of vehicle')
# Out:
# <Axes: title={'center': 'Scatter Plot between engine size and curb weight of vehicle'}, xlabel='engine_size', ylabel='curb_weight'>

# %%
df.plot('engine_size','city_mpg',kind='scatter',
                                    legend = True,
                                    figsize=(10,4),
                                    grid=True,
                                    title='Scatter Plot between engine size and curb weight of vehicle')
# Out:
# <Axes: title={'center': 'Scatter Plot between engine size and curb weight of vehicle'}, xlabel='engine_size', ylabel='city_mpg'>

# %%
df.plot('engine_size','highway_mpg',kind='scatter',
                                    legend = True,
                                    figsize=(10,4),
                                    grid=True,
                                    title='Scatter Plot between engine size and curb weight of vehicle')
# Out:
# <Axes: title={'center': 'Scatter Plot between engine size and curb weight of vehicle'}, xlabel='engine_size', ylabel='highway_mpg'>

# %% [markdown]
# #### Numeric & Categrical Data
# **Groupby**

# %%
df.groupby(by='make')['num_of_doors'].max()
# Out:
# make
# alfa-romero      2.0
# audi             4.0
# bmw              4.0
# chevrolet        4.0
# dodge            4.0
# honda            4.0
# isuzu            4.0
# jaguar           4.0
# mazda            4.0
# mercedes-benz    4.0
# mercury          2.0
# mitsubishi       4.0
# nissan           4.0
# peugot           4.0
# plymouth         4.0
# porsche          2.0
# renault          4.0
# saab             4.0
# subaru           4.0
# toyota           4.0
# volkswagen       4.0
# volvo            4.0
# Name: num_of_doors, dtype: float64

# %%
df.groupby(by='body_style')['num_of_cylinders'].max()
# Out:
# body_style
# convertible     8
# hardtop         8
# hatchback       8
# sedan          12
# wagon           6
# Name: num_of_cylinders, dtype: int64

# %% [markdown]
# **PivotTable**

# %%
df.pivot_table(values = 'num_of_cylinders',index = 'make', aggfunc='max')
# Out:
#                num_of_cylinders
# make
# alfa-romero                   6
# audi                          5
# bmw                           6
# chevrolet                     4
# dodge                         4
# honda                         4
# isuzu                         4
# jaguar                       12
# mazda                         4
# mercedes-benz                 8
# mercury                       4
# mitsubishi                    4
# nissan                        6
# peugot                        4
# plymouth                      4
# porsche                       8
# renault                       4
# saab                          4
# subaru                        4
# toyota                        6
# volkswagen                    5
# volvo                         6

# %%
df.pivot_table(values = 'num_of_doors',index = 'make', aggfunc='max')
# Out:
#                num_of_doors
# make
# alfa-romero             2.0
# audi                    4.0
# bmw                     4.0
# chevrolet               4.0
# dodge                   4.0
# honda                   4.0
# isuzu                   4.0
# jaguar                  4.0
# mazda                   4.0
# mercedes-benz           4.0
# mercury                 2.0
# mitsubishi              4.0
# nissan                  4.0
# peugot                  4.0
# plymouth                4.0
# porsche                 2.0
# renault                 4.0
# saab                    4.0
# subaru                  4.0
# toyota                  4.0
# volkswagen              4.0
# volvo                   4.0

# %%
df.pivot_table(values='city_mpg',index='make',aggfunc='min')
# Out:
#                city_mpg
# make
# alfa-romero          19
# audi                 16
# bmw                  15
# chevrolet            38
# dodge                19
# honda                24
# isuzu                24
# jaguar               13
# mazda                16
# mercedes-benz        14
# mercury              19
# mitsubishi           19
# nissan               17
# peugot               18
# plymouth             19
# porsche              17
# renault              23
# saab                 19
# subaru               23
# toyota               19
# volkswagen           19
# volvo                17

# %%
df.pivot_table(values='city_mpg',index='make',aggfunc='max')
# Out:
#                city_mpg
# make
# alfa-romero          21
# audi                 24
# bmw                  23
# chevrolet            47
# dodge                37
# honda                49
# isuzu                38
# jaguar               15
# mazda                36
# mercedes-benz        22
# mercury              19
# mitsubishi           37
# nissan               45
# peugot               28
# plymouth             37
# porsche              19
# renault              23
# saab                 21
# subaru               32
# toyota               38
# volkswagen           37
# volvo                26

# %% [markdown]
# **Line Chart**

# %%
df['num_of_cylinders'].plot(kind='line')
# Out:
# <Axes: >

# %%
df['engine_size'].plot(kind='line')
# Out:
# <Axes: >

# %%
df.plot('body_style','price',kind='line')
# Out:
# <Axes: xlabel='body_style'>

# %% [markdown]
# ### Multivariate Analysis

# %%
df.corr(numeric_only=True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434334  0.385675  0.197735  0.540286
# wheel_base             0.434334    1.000000  0.871674  0.795635  0.586421
# length                 0.385675    0.871674  1.000000  0.841118  0.491029
# width                  0.197735    0.795635  0.841118  1.000000  0.279210
# height                 0.540286    0.586421  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.775265  0.877728  0.867032  0.295572
# num_of_cylinders      -0.019503    0.340349  0.430672  0.545007 -0.013995
# engine_size            0.017968    0.567020  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250870  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.351295  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.364688 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467683 -0.670909 -0.642704 -0.048640
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# * 1. Scatter Plot for wheel base and length:- If the wheel base is increased so the length of vehicle will be increased, And There is Positive direction because plot is going in increament order  and Strong Strenth because the plot is strongly clossness.
# * 2. Pair Plot showing the combination of Histogram and Scatter Plot which is for multivariate analysis.
# * 3. Heatmap showing the Correlation between the variables which ranges from -0.5 to +1, -0.5 to +0.5 shows negative correlation, And +0.5 to 1 shows Positive correlation, and also correlation is indicates in different colours.
# * 4. Pie Chart of fuel type in cars shows There is 98.5 percent of cars which is having engine at front and There is only 1.5 percent of cars which having engine at rear
